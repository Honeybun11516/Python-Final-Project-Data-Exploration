# %% [markdown]
# ###What Clothing Item Do Women Purchase Most?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy
from statsmodels.stats.proportion import proportions_chisquare

# %%
Clothing = pd.read_csv("C:/Users/15756/Downloads/New Folder With Items 2 (1)/New Folder With Items 2/women.csv/women.csv")

# %%
Clothing.dropna()
Clothing.head(10)
# Out:
#   category                   subcategory  \
# 0    women                      T-shirts
# 1    women                Soutiens-gorge
# 2    women            Pantalons & Shorts
# 3    women               Robes imprimées
# 4    women                      T-shirts
# 5    women               Robes imprimées
# 6    women  Combinaisons & Grenouillères
# 7    women  Combinaisons & Grenouillères
# 8    women            Pantalons & Shorts
# 9    women            Pantalons & Shorts
#
#                                                 name  current_price  \
# 0  T-shirt boutonné à manches courtes et imprimé ...          23.99
# 1       Plus Soutiens-gorge avec fermeture à l'avant          15.99
# 2  Pantalon décontracté à taille élastique de cou...          25.99
# 3            Robe midi décontractée à imprimé floral          23.99
# 4                            T-shirt brodé de fleurs          15.99
# 5               Robe longue à imprimé floral vintage          33.99
# ...

# %%
list(Clothing)
# Out:
# ['category',
#  'subcategory',
#  'name',
#  'current_price',
#  'raw_price',
#  'currency',
#  'discount',
#  'likes_count',
#  'is_new',
#  'brand',
#  'brand_url',
#  'codCountry',
#  'variation_0_color',
#  'variation_1_color',
#  'variation_0_thumbnail',
#  'variation_0_image',
#  'variation_1_thumbnail',
#  'variation_1_image',
#  'image_url',
#  'url',
#  'id',
#  'model']

# %%
Clothing1 = Clothing[['subcategory', 'category', 'likes_count']]

# %%
Clothing.dropna()
Clothing1.head(10)
# Out:
#                     subcategory category  likes_count
# 0                      T-shirts    women          313
# 1                Soutiens-gorge    women         4603
# 2            Pantalons & Shorts    women         5564
# 3               Robes imprimées    women         1262
# 4                      T-shirts    women         4485
# 5               Robes imprimées    women         2419
# 6  Combinaisons & Grenouillères    women           33
# 7  Combinaisons & Grenouillères    women         4132
# 8            Pantalons & Shorts    women         3095
# 9            Pantalons & Shorts    women         4367

# %%
Clothing1.loc[:,"subcategory"]
# Out:
# 0                  T-shirts
# 1            Soutiens-gorge
# 2        Pantalons & Shorts
# 3           Robes imprimées
# 4                  T-shirts
#                 ...
# 14804        Soutiens-gorge
# 14805               Hoodies
# 14806           Pajama Sets
# 14807    Blouses & Chemises
# 14808    Pantalons & Shorts
# Name: subcategory, Length: 14809, dtype: object
